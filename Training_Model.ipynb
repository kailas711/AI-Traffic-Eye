# %%
# !mkdir datasets
# %cd datasets
# !pip install ultralytics --quiet
# !pip install roboflow --quiet
# Out:
# /content/datasets
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.5/605.5 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 934.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.9 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="yG44Wj536Zq32qm1kv7o")
project = rf.workspace("kumaraguru-college-of-technology-gfdmc").project("nested-object-detection")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.138, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Nested-Object-Detection-1 in yolov8:: 100%|██████████| 1427/1427 [00:00<00:00, 1780.57it/s]

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Train the model
model.train(data="/content/datasets/Nested-Object-Detection-1/data.yaml", epochs=100, imgsz=640,optimizer = "Adam")
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/datasets/runs/detect/train6/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.138 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
# val: Scanning /content/datasets/Nested-Object-Detection-1/valid/labels.cache... 55 images, 0 backgrounds, 0 corrupt: 100%|██████████| 55/55 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:03<00:00,  1.15it/s]
#                    all         55        103      0.892      0.825      0.903      0.696
#             Motorcycle         55         74       0.93      0.892      0.972      0.799
#             Pedestrian         55         29      0.853      0.759      0.834      0.594
# Speed: 6.8ms preprocess, 15.3ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/detect/val
# array([    0.79881,     0.59394])

# %%
model.predict("/content/Test.jpg", save=True, conf=0.5)
# Out:
# image 1/1 /content/Test.jpg: 224x320 1 motorcycle, 1 person, 1 scooter, 12.3ms
# Speed: 1.6ms preprocess, 12.3ms inference, 4.4ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'motorcycle', 1: 'person', 2: 'scooter'}
#  orig_img: array([[[139, 186, 213],
#          [143, 189, 213],
#          [147, 188, 210],
#          ...,
#          [100, 105, 114],
#          [103, 108, 117],
#          [101, 106, 115]],
#
#         [[130, 175, 202],
#          [137, 181, 205],
#          [142, 183, 205],
#          ...,
#          [101, 106, 115],
#          [102, 107, 116],
#          [ 99, 104, 113]],
#
#         [[123, 167, 191],
#          [133, 175, 198],
#          [142, 181, 203],
#          ...,
#          [104, 106, 116],
#          [100, 105, 114],
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !zip -r /content/file.zip /content/datasets

from google.colab import files
files.download("/content/file.zip")
# Out:
#   adding: content/datasets/ (stored 0%)
#   adding: content/datasets/runs/ (stored 0%)
#   adding: content/datasets/runs/detect/ (stored 0%)
#   adding: content/datasets/runs/detect/train/ (stored 0%)
#   adding: content/datasets/runs/detect/train/weights/ (stored 0%)
#   adding: content/datasets/runs/detect/train/args.yaml (deflated 51%)
#   adding: content/datasets/runs/detect/val/ (stored 0%)
#   adding: content/datasets/runs/detect/val/val_batch1_pred.jpg (deflated 5%)
#   adding: content/datasets/runs/detect/val/confusion_matrix_normalized.png (deflated 31%)
#   adding: content/datasets/runs/detect/val/PR_curve.png (deflated 20%)
#   adding: content/datasets/runs/detect/val/val_batch2_pred.jpg (deflated 6%)
#   adding: content/datasets/runs/detect/val/val_batch2_labels.jpg (deflated 6%)
#   adding: content/datasets/runs/detect/val/val_batch0_pred.jpg (deflated 6%)
#   adding: content/datasets/runs/detect/val/val_batch1_labels.jpg (deflated 6%)
# ...
